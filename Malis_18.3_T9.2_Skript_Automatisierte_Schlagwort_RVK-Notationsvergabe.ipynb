# %% [markdown]
# # Schritt 1
# 1.1: Ermitteln des umzusystematisierenden Bestands mit SQL-Befehl, Ausgabe: csv-Datei
# 1.2: sortiert nach Spalten (Signaturen, Mediennummern, Kurztitel, Autor, Reihentitel, ISBN, neue Notation, neue Schlagwörter, neue Gesamtsignatur)
# 1.3: Signaturen numerisch aufsteigend sortieren mit zuvor geschriebenem Makro (statt P1, P10, P100 > P1, P2, P3 ...)

# %%
import urllib.request
import pandas as pd

# %%
# Set the source url
url = "https://raw.githubusercontent.com/adalka/Malis18_T9.2_Automatisierte_Schlagwort_RVK-Notationsvergabe/master/2019-05-27_P1000_sortiert_mit_ISBN_Exnr_als_Text.csv?token=AL2CQ2TCOZRARVEC46DAP4S5CCG5U"
apc_file = "2019-05-27_P1000_sortiert_mit_ISBN_Exnr_als_Text.csv"

# %%
urllib.request.urlretrieve(url, apc_file)
# Out:
# ('2019-05-27_P1000_sortiert_mit_ISBN_Exnr_als_Text.csv',
#  <http.client.HTTPMessage at 0x194e2f1feb8>)

# %%
# Datei war zu groß "We can't make this file beautiful and searchable because it's too large."
# Set the new source url
# Datei enthält Fehler "We can make this file beautiful and searchable if this error is corrected: Illegal quoting in line 4"
# We can make this file beautiful and searchable if this error is corrected: It looks like row 2 should actually have 1 column, instead of 2. in line 1."
# hilfreich: https://gist.github.com/jexp/2faa74b983907b43586d
# hilfreich: https://help.github.com/en/articles/rendering-csv-and-tsv-data

# %% [markdown]
# # Schritt 2
# 2.1: csv-Datei aufs Wesentliche reduziert: Titelnummern und ISBN

# %%
# csv-Datei war nicht durch Komma, sondern Semikolon getrennt, öffnen im Notepad > Semikolons ersetzt durch Kommas

# %%
apcs = pd.read_csv(apc_file)

# %%
apcs
# Out:
#        EXEMPLARNR           ISBN
# 0    1.586749e+09          FALSE
# 1    1.586750e+09          FALSE
# 2    1.586751e+09          FALSE
# 3    1.586752e+09          FALSE
# 4    1.586754e+09  3-85460-115-8
# 5    1.586755e+09  3-85460-111-5
# 6    2.136820e+08          FALSE
# 7    1.586757e+09  91-7192-927-4
# 8    1.586758e+09  3-88609-200-3
# 9    1.586759e+09  0-521-23742-4
# 10   1.586765e+09  3-496-02548-4
# 11   1.586768e+09  3-496-02550-6
# 12   1.586932e+09          FALSE
# 13   5.032740e+08  3-87065-560-7
# 14   1.586936e+09  3-8053-1537-6
# 15   1.586942e+09  91-506-1093-7
# 16   1.586943e+09  91-506-1084-8
# 17   1.586944e+09          FALSE
# 18   1.586946e+09          FALSE
# 19   1.586949e+09          FALSE
# 20   1.586952e+09          FALSE
# 21   1.586954e+09          FALSE
# 22   1.586958e+09          FALSE
# 23   2.210330e+08  3-923166-43-5
# 24   4.078390e+08          FALSE
# 25   1.586962e+09          FALSE
# 26   1.586966e+09          FALSE
# 27   1.586968e+09          FALSE
# 28   1.586974e+09          FALSE
# 29   1.586978e+09  3-8067-0200-4
# ..            ...            ...
# 970  2.157710e+08          FALSE
# 971  2.157700e+08          FALSE
# 972  1.590649e+09          FALSE
# 973  1.590652e+09          FALSE
# 974  1.590654e+09          FALSE
# 975  1.590660e+09  3-406-06775-1
# 976  1.590665e+09          FALSE
# 977  1.590667e+09          FALSE
# 978  1.590669e+09          FALSE
# 979  1.590670e+09          FALSE
# 980  1.590671e+09          FALSE
# 981  1.590674e+09          FALSE
# 982  1.590676e+09          FALSE
# 983  1.590677e+09          FALSE
# 984  1.590686e+09          FALSE
# 985  1.590687e+09          FALSE
# 986  1.590688e+09          FALSE
# 987  1.590689e+09  3-929055-36-8
# 988  1.590690e+09          FALSE
# 989  1.590691e+09          FALSE
# 990  1.590693e+09          FALSE
# 991  1.590694e+09          FALSE
# 992  1.590695e+09          FALSE
# 993  1.590696e+09          FALSE
# 994  1.590697e+09          FALSE
# 995  1.590698e+09          FALSE
# 996  1.590699e+09          FALSE
# 997  1.590700e+09          FALSE
# 998  1.590701e+09          FALSE
# 999  1.590702e+09          FALSE
#
# [1000 rows x 2 columns]

# %% [markdown]
# # Schritt 3
# 3.1: csv-Datei korrigieren: Exemplarnr. und ISBN als Text
# 3.2: in csv-Datei alle leeren Zeilen in Spalte "ISBN" in "FALSE" benannt
# 3.3: alle Semikolons ersetzt durch Kommas

# %%
# csv-Datei war nicht durch Komma, sondern Semikolon getrennt, öffnen im Notepad > Semikolons ersetzt durch Kommas
# leere Zeilen mit FALSE ausgefüllt: Markieren des Zellbereichs, dessen Leerzellen ausgefüllt werden sollen; Befehl GEHE ZU (Tastenkombination STRG G). Schaltfläche INHALTE, Aktivieren von LEERZELLEN
# Gleichheitszeichen eingeben, Taste PFEIL OBEN, STRG EINGABE 
# alle leeren Zeilen werden mit "FALSE" ausgefüllt, sodass man weiß, dass diese keine ISBN enthalten

# %% [markdown]
# # Schritt 4
# 4.1: alle obigen url.lib request wiederholt, durchlaufen lassen
# 4.2: apcs werden leider nicht als "Text", sondern als "Zahl" dargestellt (EXEMPLARNR muss aber lesbar bleiben, da sie dem genauen Titel zugewiesen wird)
# 4.3: durch folgenden import behoben:

# %%
import csv
import csv
with open('2019-05-27_P1000_sortiert_mit_ISBN_Exnr_als_Text.csv', newline='') as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['EXEMPLARNR', 'ISBN']
# ['1586749001', 'FALSE']
# ['1586750001', 'FALSE']
# ['1586751001', 'FALSE']
# ['1586752001', 'FALSE']
# ['1586754001', '3-85460-115-8']
# ['1586755001', '3-85460-111-5']
# ['213682005', 'FALSE']
# ['1586757001', '91-7192-927-4']
# ['1586758001', '3-88609-200-3']
# ['1586759001', '0-521-23742-4']
# ['1586765001', '3-496-02548-4']
# ['1586768001', '3-496-02550-6']
# ['1586932001', 'FALSE']
# ['503274002', '3-87065-560-7']
# ['1586936001', '3-8053-1537-6']
# ['1586942001', '91-506-1093-7']
# ['1586943001', '91-506-1084-8']
# ['1586944001', 'FALSE']
# ['1586946001', 'FALSE']
# ['1586949001', 'FALSE']
# ['1586952001', 'FALSE']
# ['1586954001', 'FALSE']
# ['1586958001', 'FALSE']
# ['221033005', '3-923166-43-5']
# ['407839001', 'FALSE']
# ['1586962001', 'FALSE']
# ['1586966001', 'FALSE']
# ['1586968001', 'FALSE']
# ['1586974001', 'FALSE']
# ['1586978001', '3-8067-0200-4']
# ['1586982001', 'FALSE']
# ['1586983001', 'FALSE']
# ['1586985001', 'FALSE']
# ['1586986001', '3-05-000572-6']
# ['1586988001', '3-05-002020-2']
# ['1586993001', '87-7288-053-8']
# ['213732006', '3-402-06081-7']
# ['1586995001', 'FALSE']
# ['1586996001', 'FALSE']
# ['1587000001', 'FALSE']
# ['402249001', 'FALSE']
# ['1683229001', '87-88415-38-4']
# ['1684592001', '87-88415-38-4']
# ['1683230001', '978-87-88415-62-9']
# ['1683228001', '978-87-88415-72-8']
# ['1586999001', 'FALSE']
# ['1587001001', 'FALSE']
# ['1587002001', 'FALSE']
# ['1587003001', '87-7288-581-5']
# ['1587005001', '87-7288-581-5']
# ['1587004001', '87-7288-581-5']
# ['1587006001', '87-7288-586-6']
# ['402248001', 'FALSE']
# ['1590405001', '2-88028-036-2']
# ['1587016001', '3-7749-1686-1']
# ['1587019001', '0-906780-24-1']
# ['1587526001', '90-6191-673-9']
# ['1587542001', '0-12-348150-3']
# ['1587548001', '3-89473-613-5']
# ['1587606001', 'FALSE']
# ['1587607001', 'FALSE']
# ['1587553001', '0-906780-07-1']
# ['1587557001', 'FALSE']
# ['1587560001', 'FALSE']
# ['1587564001', '2-7018-0031-5']
# ['1587567001', '84-500-8553-5']
# ['1587615001', 'FALSE']
# ['1587618001', 'FALSE']
# ['1587575001', '963-563-050-6']
# ['1587588001', '3-7749-2664-6']
# ['1587591001', 'FALSE']
# ['19759002', '3-7995-7024-1']
# ['1587635001', 'FALSE']
# ['1587639001', 'FALSE']
# ['1587598001', 'FALSE']
# ['1587661001', 'FALSE']
# ['1587665001', 'FALSE']
# ['1587666001', 'FALSE']
# ['1587667001', 'FALSE']
# ['1587669001', 'FALSE']
# ['1587670001', 'FALSE']
# ['1595224001', 'FALSE']
# ['1595245001', 'FALSE']
# ['1595261001', 'FALSE']
# ['1595263001', 'FALSE']
# ['1595264001', 'FALSE']
# ['1595265001', 'FALSE']
# ['1595266001', 'FALSE']
# ['1595267001', 'FALSE']
# ['1595269001', 'FALSE']
# ['1595270001', 'FALSE']
# ['1595271001', '3-7749-1100-2']
# ['1595246001', 'FALSE']
# ['1595248001', 'FALSE']
# ['1595254001', 'FALSE']
# ['1595255001', 'FALSE']
# ['1595256001', 'FALSE']
# ['1595257001', 'FALSE']
# ['1595258001', 'FALSE']
# ['1595259001', 'FALSE']
# ['1596201001', 'FALSE']
# ['1595661001', 'FALSE']
# ['1595663001', 'FALSE']
# ['1595665001', 'FALSE']
# ['1595666001', 'FALSE']
# ['1596204001', 'FALSE']
# ['1595668001', 'FALSE']
# ['1595670001', 'FALSE']
# ['1595672001', 'FALSE']
# ['1595675001', 'FALSE']
# ['1595679001', 'FALSE']
# ['1595680001', 'FALSE']
# ['1607946001', 'FALSE']
# ['1607947001', 'FALSE']
# ['1607948001', 'FALSE']
# ['1607949001', 'FALSE']
# ['1607950001', 'FALSE']
# ['1607953001', 'FALSE']
# ['1607951001', 'FALSE']
# ['1608101001', 'FALSE']
# ['1608102001', 'FALSE']
# ['1608103001', 'FALSE']
# ['1608116001', 'FALSE']
# ['1608118001', 'FALSE']
# ['1608120001', 'FALSE']
# ['1608121001', 'FALSE']
# ['1608123001', 'FALSE']
# ['1608128001', 'FALSE']
# ['1608129001', 'FALSE']
# ['1608131001', 'FALSE']
# ['1608132001', 'FALSE']
# ['1608133001', 'FALSE']
# ['1608104001', 'FALSE']
# ['1608135001', 'FALSE']
# ['1608136001', 'FALSE']
# ['1608137001', '3-7749-1820-1']
# ['1608154001', '3-7749-1821-X']
# ['1608143001', '3-7749-1822-8']
# ['1608147001', '3-7749-1931-3']
# ['1608149001', 'FALSE']
# ['1608151001', 'FALSE']
# ['1608153001', 'FALSE']
# ['1608105001', 'FALSE']
# ['1608106001', 'FALSE']
# ['1608107001', 'FALSE']
# ['1608108001', 'FALSE']
# ['1608111001', 'FALSE']
# ['1608113001', 'FALSE']
# ['1608114001', 'FALSE']
# ['1596060001', 'FALSE']
# ['1608200001', 'FALSE']
# ['1608205001', 'FALSE']
# ['1608208001', 'FALSE']
# ['1608218001', 'FALSE']
# ['1608220001', 'FALSE']
# ['1608222001', 'FALSE']
# ['1608223001', 'FALSE']
# ['1608224001', 'FALSE']
# ['1608225001', 'FALSE']
# ['1608228001', 'FALSE']
# ['1596061001', 'FALSE']
# ['1608231001', 'FALSE']
# ['1608237001', 'FALSE']
# ['1608246001', 'FALSE']
# ['1608248001', 'FALSE']
# ['1608250001', 'FALSE']
# ['', 'FALSE']
# ['1608259001', 'FALSE']
# ['1608260001', 'FALSE']
# ['1608261001', 'FALSE']
# ['1608262001', 'FALSE']
# ['1596064001', 'FALSE']
# ['1608263001', 'FALSE']
# ['1608264001', 'FALSE']
# ['1608265001', 'FALSE']
# ['1608266001', 'FALSE']
# ['1608273001', 'FALSE']
# ['1608267001', 'FALSE']
# ['1608268001', 'FALSE']
# ['1608269001', 'FALSE']
# ['1608270001', 'FALSE']
# ['1608271001', 'FALSE']
# ['1608175001', 'FALSE']
# ['1608272001', 'FALSE']
# ['1608275001', 'FALSE']
# ['1608276001', 'FALSE']
# ['1608277001', 'FALSE']
# ['1608281001', 'FALSE']
# ['1608283001', 'FALSE']
# ['1608286001', '83-01-03011-9']
# ['1608288001', '83-01-03444-0']
# ['1608290001', 'FALSE']
# ['1608292001', '83-01-04331-8']
# ['1608180001', 'FALSE']
# ['1608293001', '83-01-04498-5']
# ['1608295001', '83-01-04984-7']
# ['1608299001', '83-01-05351-8']
# ['1608300001', '83-01-05825-0']
# ['1608302001', '83-01-06209-6']
# ['1608303001', '83-01-06487-0']
# ['1608304001', '83-01-06825-6']
# ['1608305001', '83-01-07235-0']
# ['1608309001', '83-01-07860-X']
# ['1608311001', '83-01-08048-5']
# ['1608183001', 'FALSE']
# ['1608312001', '83-01-08437-5']
# ['1608313001', '83-01-08783-8']
# ['1608314001', '83-01-09114-2']
# ['1608315001', '83-01-09489-3']
# ['1608316001', '83-01-09903-8']
# ['1608190001', 'FALSE']
# ['1608196001', 'FALSE']
# ['1608199001', 'FALSE']
# ['1608371001', 'FALSE']
# ['1608372001', 'FALSE']
# ['1608373001', 'FALSE']
# ['1608374001', 'FALSE']
# ['1608377001', 'FALSE']
# ['1608378001', 'FALSE']
# ['1608379001', 'FALSE']
# ['1608380001', 'FALSE']
# ['1608381001', 'FALSE']
# ['1608382001', 'FALSE']
# ['1608383001', 'FALSE']
# ['1608384001', 'FALSE']
# ['1608385001', 'FALSE']
# ['1608386001', 'FALSE']
# ['1608388001', 'FALSE']
# ['1608392001', 'FALSE']
# ['1608410001', 'FALSE']
# ['1608407001', 'FALSE']
# ['1608412001', 'FALSE']
# ['1608414001', 'FALSE']
# ['1608415001', 'FALSE']
# ['1608393001', 'FALSE']
# ['1608394001', 'FALSE']
# ['1608395001', 'FALSE']
# ['1608397001', 'FALSE']
# ['1608399001', 'FALSE']
# ['1608398001', 'FALSE']
# ['1608400001', 'FALSE']
# ['1608409001', 'FALSE']
# ['407276001', 'FALSE']
# ['1608419001', 'FALSE']
# ['1608420001', 'FALSE']
# ['1608421001', 'FALSE']
# ['1608422001', 'FALSE']
# ['1608423001', 'FALSE']
# ['1608425001', 'FALSE']
# ['1608426001', '3-326-00157-6']
# ['1608428001', 'FALSE']
# ['1608430001', 'FALSE']
# ['1608432001', 'FALSE']
# ['1608431001', '3-326-00574-1']
# ['1608433001', 'FALSE']
# ['1608455001', 'FALSE']
# ['1608456001', 'FALSE']
# ['1608457001', 'FALSE']
# ['1608459001', 'FALSE']
# ['1608434001', 'FALSE']
# ['1608435001', 'FALSE']
# ['1608436001', 'FALSE']
# ['1608449001', 'FALSE']
# ['1608450001', 'FALSE']
# ['1608453001', 'FALSE']
# ['1608451001', 'FALSE']
# ['1608460001', 'FALSE']
# ['1608471001', 'FALSE']
# ['1608473001', 'FALSE']
# ['1608474001', 'FALSE']
# ['1608476001', 'FALSE']
# ['1608478001', 'FALSE']
# ['1608479001', 'FALSE']
# ['1608461001', 'FALSE']
# ['1608462001', 'FALSE']
# ['1608463001', 'FALSE']
# ['1608464001', 'FALSE']
# ['1608465001', 'FALSE']
# ['1608466001', 'FALSE']
# ['1608467001', 'FALSE']
# ['1608469001', 'FALSE']
# ['1587711001', 'FALSE']
# ['1587722001', 'FALSE']
# ['1587728001', '0-11-700588-6']
# ['1587729001', '0-11-700589-4']
# ['1587731001', 'FALSE']
# ['1587735001', '0-11-700842-7']
# ['1587739001', 'FALSE']
# ['1587738001', 'FALSE']
# ['1587740001', 'FALSE']
# ['1587741001', 'FALSE']
# ['1587742001', 'FALSE']
# ['1587743001', 'FALSE']
# ['1587744001', 'FALSE']
# ['1587745001', 'FALSE']
# ['1587746001', 'FALSE']
# ['1587747001', 'FALSE']
# ['1587748001', 'FALSE']
# ['1587749001', 'FALSE']
# ['1587751001', 'FALSE']
# ['1587753001', 'FALSE']
# ['1587755001', 'FALSE']
# ['1587756001', 'FALSE']
# ['400872001', 'FALSE']
# ['402530001', 'FALSE']
# ['403416001', 'FALSE']
# ['405071001', 'FALSE']
# ['408010001', 'FALSE']
# ['1564994001', 'FALSE']
# ['1638920001', 'FALSE']
# ['1655908001', 'FALSE']
# ['1690283001', 'FALSE']
# ['1712549001', 'FALSE']
# ['1739205001', 'FALSE']
# ['1752322001', 'FALSE']
# ['1769545001', 'FALSE']
# ['1588180001', 'FALSE']
# ['1588183001', '0-901714-54-2']
# ['1588197001', 'FALSE']
# ['1588199001', 'FALSE']
# ['1588203001', '3-87439-106-X']
# ['1588224001', '0-906090-00-8']
# ['1588221001', 'FALSE']
# ['1588228001', 'FALSE']
# ['1588231001', 'FALSE']
# ['1588232001', 'FALSE']
# ['1588237001', '91-36-86949-X']
# ['213960002', 'FALSE']
# ['1588239001', 'FALSE']
# ['1588245001', '0-521-36573-2']
# ['1588247001', 'FALSE']
# ['1588248001', 'FALSE']
# ['1588255001', '3-534-07058-5']
# ['1588259001', '3-534-04003-1']
# ['1588261001', '0-85976-101-0']
# ['1588267001', '87-7288-561-0']
# ['1588269001', '87-7288-561-0']
# ['1588273001', 'FALSE']
# ['1588281001', 'FALSE']
# ['1588285001', 'FALSE']
# ['1588286001', 'FALSE']
# ['1588316001', '0-12-588020-0']
# ['1588338001', 'FALSE']
# ['1588349001', 'FALSE']
# ['1588352001', 'FALSE']
# ['1588346001', 'FALSE']
# ['406909001', 'FALSE']
# ['1588319001', '3-17-079029-3']
# ['1588320001', '0-86159-085-6']
# ['1588324001', 'FALSE']
# ['406719001', 'FALSE']
# ['1588325001', '0-7141-1395-6']
# ['1588326001', 'FALSE']
# ['1588327001', 'FALSE']
# ['1606046001', 'FALSE']
# ['1606051001', 'FALSE']
# ['1609212001', '3-88467-041-7']
# ['400575001', 'FALSE']
# ['1588328001', 'FALSE']
# ['1554860001', '978-3-9807996-8-3']
# ['1638326001', '978-3-9813109-2-4']
# ['1700770001', 'FALSE']
# ['1572719001', 'FALSE']
# ['1717719001', '978-3-9813109-9-3']
# ['1743813001', '978-3-9816873-3-0']
# ['1782061001', '978-3-9816873-9-2']
# ['1606267001', 'FALSE']
# ['1606269001', 'FALSE']
# ['1606049001', 'FALSE']
# ['1588360001', 'FALSE']
# ['8689003', 'FALSE']
# ['1588363001', 'FALSE']
# ['1588366001', 'FALSE']
# ['1588367001', 'FALSE']
# ['712204002', 'FALSE']
# ['203165002', 'FALSE']
# ['1588391001', 'FALSE']
# ['1588392001', 'FALSE']
# ['1588393001', 'FALSE']
# ['1588394001', '82-7126-094-4']
# ['1588412001', 'FALSE']
# ['1588413001', 'FALSE']
# ['1589764001', '82-7126-346-3']
# ['1589773001', '82-7126-347-1']
# ['1589849001', '82-7126-357-8']
# ['1589853001', '82-7126-417-6']
# ['1589856001', '82-7126-453-2']
# ['1589811001', '82-7126-420-6']
# ['1589812001', 'FALSE']
# ['406896001', 'FALSE']
# ['406962001', 'FALSE']
# ['1588416001', 'FALSE']
# ['1588417001', 'FALSE']
# ['1588418001', 'FALSE']
# ['1589817001', 'FALSE']
# ['1589822001', '82-7126-442-7']
# ['1589832001', 'FALSE']
# ['1589834001', 'FALSE']
# ['1589841001', '3-929055-26-0']
# ['1589872001', '3-458-32213-2']
# ['1589874001', 'FALSE']
# ['127222002', '3-87358-156-6']
# ['1589876001', '3-87358-283-X']
# ['1589877001', '0-946897-37-9']
# ['1589882001', '0-946897-28-X']
# ['1589883001', '0-946897-43-3']
# ['1589886001', '3-87157-139-3']
# ['', 'FALSE']
# ['1589892001', 'FALSE']
# ['1589895001', 'FALSE']
# ['1589897001', 'FALSE']
# ['1589898001', 'FALSE']
# ['1590122001', 'FALSE']
# ['1590124001', 'FALSE']
# ['1590125001', 'FALSE']
# ['1590127001', 'FALSE']
# ['1590129001', 'FALSE']
# ['1590131001', 'FALSE']
# ['1590132001', 'FALSE']
# ['1590133001', '0-946897-57-3']
# ['1590400001', '3-921618-02-9']
# ['1590137001', '0-946897-58-1']
# ['1590141001', '3-929864-00-2']
# ['16742004', 'FALSE']
# ['1590144001', 'FALSE']
# ['1590168001', 'FALSE']
# ['1590170001', '3-85124-146-0']
# ['406965001', 'FALSE']
# ['1590352001', '3-900773-04-1']
# ['1590354001', '3-900773-07-6']
# ['1590358001', '3-900773-08-4']
# ['1590679001', '3-900773-06-8']
# ['1590680001', '3-900773-11-4']
# ['1590172001', '0-947846-02-6']
# ['1590174001', '83-85599-20-7']
# ['1590178001', 'FALSE']
# ['100663002', '3-7848-4042-6']
# ['1590181001', 'FALSE']
# ['1590183001', 'FALSE']
# ['1590371001', 'FALSE']
# ['1590372001', 'FALSE']
# ['1590374001', 'FALSE']
# ['1590187001', 'FALSE']
# ['1590188001', 'FALSE']
# ['1590191001', 'FALSE']
# ['1590194001', '3-928957-01-5']
# ['1590195001', 'FALSE']
# ['1590367001', '3-928957-02-3']
# ['1590379001', 'FALSE']
# ['1590380001', 'FALSE']
# ['1590382001', '3-928957-03-1']
# ['1590383001', '90-6255-093-2']
# ['1590934001', '0-905853-06-7']
# ['1590937001', '0-905853-16-4']
# ['1590938001', '0-905853-33-4']
# ['1590389001', '0-905853-32-6']
# ['1590393001', 'FALSE']
# ['1590394001', 'FALSE']
# ['1590397001', 'FALSE']
# ['1590399001', '3-929645-01-7']
# ['1590412001', '3-929645-01-9']
# ['1590415001', 'FALSE']
# ['1590418001', 'FALSE']
# ['1590420001', 'FALSE']
# ['214267002', 'FALSE']
# ['1590426001', '3-11-004752-7']
# ['1590429001', 'FALSE']
# ['1590431001', '3-529-01813-9']
# ['214268002', 'FALSE']
# ['1590435001', '3-205-03658-1']
# ['1590436001', 'FALSE']
# ['1590438001', 'FALSE']
# ['1590441001', 'FALSE']
# ['1590443001', 'FALSE']
# ['1590445001', 'FALSE']
# ['1590447001', 'FALSE']
# ['1704057001', 'FALSE']
# ['1590478001', '83-85463-20-8']
# ['1590479001', 'FALSE']
# ['1590483001', 'FALSE']
# ['1590484001', 'FALSE']
# ['1590486001', 'FALSE']
# ['1590488001', 'FALSE']
# ['402409001', '3-9802601-7-8']
# ['1590492001', 'FALSE']
# ['1590495001', 'FALSE']
# ['1590496001', 'FALSE']
# ['214284002', 'FALSE']
# ['1590502001', '91-506-0481-3']
# ['1590503001', 'FALSE']
# ['1590504001', 'FALSE']
# ['1590506001', 'FALSE']
# ['1590512001', '3-8204-6752-1']
# ['1590521001', 'FALSE']
# ['406827001', '83-04-01119-0']
# ['1590535001', '83-231-0541-3']
# ['1590546001', 'FALSE']
# ['1590552001', '3-89442-213-0']
# ['1590557001', 'FALSE']
# ['1590589001', 'FALSE']
# ['1590592001', 'FALSE']
# ['1670145001', 'FALSE']
# ['1670146001', 'FALSE']
# ['1670147001', 'FALSE']
# ['1670148001', 'FALSE']
# ['1670149001', 'FALSE']
# ['1670150001', 'FALSE']
# ['1670151001', 'FALSE']
# ['1670152001', 'FALSE']
# ['1540531001', 'FALSE']
# ['1540568001', 'FALSE']
# ['1540570001', 'FALSE']
# ['1553031001', 'FALSE']
# ['1590673001', 'FALSE']
# ['1590940001', 'FALSE']
# ['1590941001', '3-8053-1601-1']
# ['1590944001', 'FALSE']
# ['1590945001', '87-7304-159-9']
# ['1590946001', 'FALSE']
# ['1590948001', '0-416-34190-X']
# ['1590949001', 'FALSE']
# ['1590950001', '82-90215-12-6']
# ['1590952001', '87-7288-048-1']
# ['1590953001', 'FALSE']
# ['1590954001', 'FALSE']
# ['1590955001', 'FALSE']
# ['1590957001', 'FALSE']
# ['1590958001', 'FALSE']
# ['214343002', 'FALSE']
# ['1590961001', 'FALSE']
# ['1590962001', 'FALSE']
# ['1590965001', '3-7001-0258-5']
# ['1590966001', '3-215-04441-2']
# ['1590968001', '0-12-385450-4']
# ['1590969001', '87-480-0484-7']
# ['1590971001', '87-7288-044-9']
# ['1590972001', 'FALSE']
# ['1590975001', '2-235-00729-5']
# ['1590982001', 'FALSE']
# ['1590984001', 'FALSE']
# ['1590991001', 'FALSE']
# ['1591001001', 'FALSE']
# ['1591003001', 'FALSE']
# ['1591007001', 'FALSE']
# ['1591018001', 'FALSE']
# ['1591020001', '91-85952-00-1']
# ['1591021001', 'FALSE']
# ['1591025001', 'FALSE']
# ['1591030001', '3-87760-606-7']
# ['1591032001', '0-7141-1361-1']
# ['1591033001', '0-7141-1372-7']
# ['1591036001', '91-40-03215-9']
# ['1591189001', '0-7136-2223-7']
# ['1591190001', '3-8053-0868-X']
# ['1591191001', '0-236-40024-X']
# ['1591193001', '0-7100-0432-X']
# ['1591194001', '0-7134-3476-7']
# ['1591196001', '0-7134-5958-1']
# ['1591197001', 'FALSE']
# ['1591199001', 'FALSE']
# ['1591200001', 'FALSE']
# ['1591201001', 'FALSE']
# ['1591202001', '87-418-1945-4']
# ['1591203001', 'FALSE']
# ['1591204001', 'FALSE']
# ['1591205001', 'FALSE']
# ['1591207001', 'FALSE']
# ['1591208001', 'FALSE']
# ['1591209001', 'FALSE']
# ['1595151001', 'FALSE']
# ['214454006', 'FALSE']
# ['214452006', 'FALSE']
# ['1591210001', 'FALSE']
# ['406605001', '3-430-15151-1']
# ['1591212001', 'FALSE']
# ['1591213001', 'FALSE']
# ['1591214001', '3-930811-00-6']
# ['1591217001', '3-8053-1006-4']
# ['1591218001', '3-8053-1139-7']
# ['1591219001', '3-8053-1288-1']
# ['1591220001', 'FALSE']
# ['1591221001', 'FALSE']
# ['1591222001', 'FALSE']
# ['1591225001', 'FALSE']
# ['1591228001', '83-85463-00-3']
# ['1591229001', '83-85483-74-8']
# ['1591230001', 'FALSE']
# ['1591233001', '3-7861-2185-0']
# ['1591240001', 'FALSE']
# ['1591266001', '2-88028-030-3']
# ['1591268001', 'FALSE']
# ['1591270001', 'FALSE']
# ['50725004', 'FALSE']
# ['1591271001', '3-445-01315-2']
# ['1591272001', 'FALSE']
# ['1591273001', 'FALSE']
# ['1591274001', 'FALSE']
# ['1591280001', 'FALSE']
# ['1591283001', 'FALSE']
# ['23547002', '3-7928-0347-X']
# ['1591286001', '3-534-04549-1']
# ['1591289001', 'FALSE']
# ['1591296001', 'FALSE']
# ['1765731001', '978-80-210-8455-1']
# ['1765732001', '978-80-210-8417-9']
# ['406541001', '3-7743-0144-1']
# ['1591309001', 'FALSE']
# ['1591310001', '3-88609-153-8']
# ['214585006', 'FALSE']
# ['1591311001', 'FALSE']
# ['1591312001', 'FALSE']
# ['1591313001', 'FALSE']
# ['1591314001', '3-511-09098-9']
# ['1591317001', 'FALSE']
# ['1591335001', 'FALSE']
# ['1591336001', 'FALSE']
# ['1591337001', 'FALSE']
# ['1591338001', '9963-560-71-7']
# ['1591339001', 'FALSE']
# ['17781002', 'FALSE']
# ['1595152001', 'FALSE']
# ['17784002', 'FALSE']
# ['17785002', 'FALSE']
# ['1595153001', 'FALSE']
# ['1591340001', '91-7192-572-4']
# ['1591341001', 'FALSE']
# ['1591343001', 'FALSE']
# ['1591344001', 'FALSE']
# ['1591345001', 'FALSE']
# ['1591347001', 'FALSE']
# ['1591348001', 'FALSE']
# ['1591349001', 'FALSE']
# ['1591350001', 'FALSE']
# ['226194005', 'FALSE']
# ['14815006', 'FALSE']
# ['14814007', 'FALSE']
# ['208733004', 'FALSE']
# ['14812006', 'FALSE']
# ['14812007', 'FALSE']
# ['14811006', 'FALSE']
# ['220222005', 'FALSE']
# ['226402004', 'FALSE']
# ['227144006', 'FALSE']
# ['225439009', 'FALSE']
# ['1102669007', 'FALSE']
# ['14810003', 'FALSE']
# ['202879006', 'FALSE']
# ['230103006', 'FALSE']
# ['229877007', '3-87023-062-2']
# ['215687007', 'FALSE']
# ['5995009', 'FALSE']
# ['13903008', 'FALSE']
# ['18548007', 'FALSE']
# ['113637011', '3-87023-164-5']
# ['113638012', '3-87023-165-3']
# ['19627010', 'FALSE']
# ['221319005', 'FALSE']
# ['616574006', 'FALSE']
# ['616575002', 'FALSE']
# ['20540003', '3-402-05037-4']
# ['23801005', '3-402-06318-2']
# ['124788004', '3-402-06319-0']
# ['1510324003', '978-3-402-06320-0']
# ['1508836007', '978-3-402-06321-7']
# ['1507205004', '3-402-06322-0']
# ['1593365009', '978-3-402-14830-3']
# ['1645077011', '978-3-402-14832-7']
# ['1664171011', '978-3-402-14833-4']
# ['222929002', 'FALSE']
# ['1705162008', '978-3-402-14834-1']
# ['1743175009', '978-3-402-14835-8']
# ['14809005', 'FALSE']
# ['14808006', 'FALSE']
# ['14807003', 'FALSE']
# ['14806006', 'FALSE']
# ['14816005', 'FALSE']
# ['1591352001', 'FALSE']
# ['1591526001', 'FALSE']
# ['1591527001', 'FALSE']
# ['1591528001', 'FALSE']
# ['1591529001', 'FALSE']
# ['1591532001', 'FALSE']
# ['1591538001', 'FALSE']
# ['1591539001', 'FALSE']
# ['1591543001', '3-421-01623-2']
# ['22748002', 'FALSE']
# ['22749002', 'FALSE']
# ['214713002', 'FALSE']
# ['1591548001', 'FALSE']
# ['1591551001', 'FALSE']
# ['1591553001', 'FALSE']
# ['1591554001', 'FALSE']
# ['1591556001', 'FALSE']
# ['1591557001', 'FALSE']
# ['1591560001', '3-511-09099-7']
# ['1591563001', 'FALSE']
# ['1591574001', 'FALSE']
# ['1591576001', 'FALSE']
# ['1591591001', 'FALSE']
# ['1591592001', 'FALSE']
# ['1591593001', 'FALSE']
# ['1591595001', 'FALSE']
# ['1591597001', 'FALSE']
# ['1591598001', '3-7991-5676-3']
# ['1591600001', 'FALSE']
# ['1526004002', '3-8062-0211-7']
# ['1591602001', 'FALSE']
# ['1594856001', 'FALSE']
# ['1594857001', '0-903681-07-2']
# ['1594858001', 'FALSE']
# ['1594859001', 'FALSE']
# ['406012001', '90-70197-11-1']
# ['1594864001', '90-70179-41-5']
# ['1594867001', '90-70179-41-5']
# ['1506439003', 'FALSE']
# ['1594868001', 'FALSE']
# ['1594869001', '0-06-480457-7']
# ['1594870001', 'FALSE']
# ['1594871001', '3-406-09204-7']
# ['1594872001', '3-900575-00-2']
# ['1594873001', '0-85263-424-2']
# ['1594874001', 'FALSE']
# ['1594875001', '3-7995-3310-9']
# ['1594876001', '3-7765-2095-7']
# ['1594879001', 'FALSE']
# ['1594880001', 'FALSE']
# ['1594882001', 'FALSE']
# ['1594883001', '3-7757-0502-3']
# ['1594885001', '3-922541-27-5']
# ['1594887001', 'FALSE']
# ['402966002', 'FALSE']
# ['1594889001', 'FALSE']
# ['1594891001', 'FALSE']
# ['1564795002', 'FALSE']
# ['1594893001', 'FALSE']
# ['1704361001', 'FALSE']
# ['1594895001', 'FALSE']
# ['1594897001', 'FALSE']
# ['712130005', 'FALSE']
# ['1594899001', 'FALSE']
# ['1594900001', 'FALSE']
# ['1594901001', 'FALSE']
# ['1594903001', 'FALSE']
# ['506028002', 'FALSE']
# ['1594904001', 'FALSE']
# ['1594908001', 'FALSE']
# ['1594909001', 'FALSE']
# ['1594910001', 'FALSE']
# ['1594911001', 'FALSE']
# ['300821004', '3-89053-032-X']
# ['215020005', 'FALSE']
# ['1590024001', '0-7099-0387-1']
# ['1590030001', 'FALSE']
# ['1590031001', 'FALSE']
# ['1590032001', 'FALSE']
# ['1590034001', 'FALSE']
# ['1590035001', '3-7749-1756-6']
# ['1590037001', 'FALSE']
# ['1590039001', 'FALSE']
# ['218487002', '3-87088-740-0']
# ['1590042001', 'FALSE']
# ['1590044001', 'FALSE']
# ['1590046001', '0-86159-006-6']
# ['1590047001', '0-946346-01-1']
# ['1590048001', '0-7141-1371-9']
# ['1590049001', '0-904857-02-6']
# ['1590051001', 'FALSE']
# ['1590053001', 'FALSE']
# ['1590054001', 'FALSE']
# ['1590060001', 'FALSE']
# ['1590061001', 'FALSE']
# ['1590063001', 'FALSE']
# ['1590065001', '3-7749-1816-3']
# ['1590069001', 'FALSE']
# ['1590070001', 'FALSE']
# ['1590071001', 'FALSE']
# ['1590073001', 'FALSE']
# ['1590075001', 'FALSE']
# ['1590077001', '3-7749-2318-3']
# ['215120007', 'FALSE']
# ['215117002', 'FALSE']
# ['1590079001', '0-7141-0528-7']
# ['1590080001', '3-7701-1374-8']
# ['1590082001', 'FALSE']
# ['1590083001', 'FALSE']
# ['1590085001', 'FALSE']
# ['1590087001', 'FALSE']
# ['1590088001', 'FALSE']
# ['1590089001', '91-7402-020-X']
# ['1590241001', 'FALSE']
# ['1590242001', 'FALSE']
# ['709848003', '3-7927-0789-6']
# ['1575165002', 'FALSE']
# ['1590243001', 'FALSE']
# ['1590244001', '3-7749-1120-7']
# ['1590245001', 'FALSE']
# ['1590246001', 'FALSE']
# ['1590247001', 'FALSE']
# ['1590248001', '3-515-01878-6']
# ['729446002', 'FALSE']
# ['1590249001', '0-226-43957-7']
# ['1590250001', 'FALSE']
# ['1511421002', '3-7757-0547-3']
# ['1590251001', 'FALSE']
# ['1590252001', 'FALSE']
# ['1590253001', '3-85326-949-4']
# ['1400255002', 'FALSE']
# ['1590254001', '3-430-15483-9']
# ['1590255001', 'FALSE']
# ['1590256001', 'FALSE']
# ['1590257001', 'FALSE']
# ['1590258001', '3-88226-758-5']
# ['1590261001', '87-01-81001-4']
# ['1590262001', '87-01-81011-1']
# ['1590263001', 'FALSE']
# ['1590264001', '0-500-79006-X']
# ['1590259001', 'FALSE']
# ['1590265001', 'FALSE']
# ['1590266001', 'FALSE']
# ['1590267001', 'FALSE']
# ['1590268001', '3-533-02180-7']
# ['1590269001', 'FALSE']
# ['1590270001', 'FALSE']
# ['1590271001', '90-5345-033-5']
# ['1590272001', '90-5345-048-3']
# ['1590273001', '3-922661-89-0']
# ['1590275001', 'FALSE']
# ['1590276001', 'FALSE']
# ['1590278001', 'FALSE']
# ['1590279001', 'FALSE']
# ['1590280001', 'FALSE']
# ['1590281001', '90-228-3740-8']
# ['501919005', 'FALSE']
# ['1590282001', '3-511-06935-1']
# ['1590283001', '3-928134-79-5']
# ['1590284001', '3-89590-003-6']
# ['1590286001', 'FALSE']
# ['114914002', '3-7995-4139-X']
# ['1590287001', 'FALSE']
# ['1590288001', 'FALSE']
# ['1590289001', 'FALSE']
# ['215341002', 'FALSE']
# ['1201276002', '90-801044-1-8']
# ['1590291001', '90-70482-68-1']
# ['1590299001', '80-210-0961-6']
# ['1590300001', '90-5345-049-1']
# ['1590301001', 'FALSE']
# ['1590302001', '3-924734-37-2']
# ['1590304001', 'FALSE']
# ['1590307001', '3-8233-4007-7']
# ['', 'FALSE']
# ['1590314001', 'FALSE']
# ['1590317001', 'FALSE']
# ['1590319001', 'FALSE']
# ['1590321001', '3-406-38064-6']
# ['1590323001', 'FALSE']
# ['1590324001', '3-7011-7283-8']
# ['1590325001', '3-519-07428-1']
# ['1590326001', '2-9505595-3-0']
# ['1590328001', '3-486-64832-2']
# ['802478002', '3-222-12272-5']
# ['1590330001', '3-7749-2674-3']
# ['509919002', '3-7927-1097-8']
# ['1590332001', '3-05-002601-4']
# ['1609133001', '3-515-08604-8']
# ['1609134001', '978-3-515-08938-8']
# ['1610898001', '3-515-07114-8']
# ['1610897001', '3-515-07620-4']
# ['1590339001', 'FALSE']
# ['1590341001', 'FALSE']
# ['1590373001', '3-923607-6-4']
# ['1590376001', '3-87490-560-8']
# ['1590377001', 'FALSE']
# ['1590384001', 'FALSE']
# ['1590385001', 'FALSE']
# ['1590386001', 'FALSE']
# ['1590387001', 'FALSE']
# ['1590388001', 'FALSE']
# ['1590390001', 'FALSE']
# ['1590391001', 'FALSE']
# ['1590392001', '91-506-0661-1']
# ['1590395001', 'FALSE']
# ['1590398001', 'FALSE']
# ['14787004', 'FALSE']
# ['19584005', 'FALSE']
# ['1590401001', '3-924734-31-3']
# ['1590402001', '3-8204-5167-6']
# ['1590403001', 'FALSE']
# ['1590404001', '3-8053-0480-3']
# ['13653002', '3-412-06471-8']
# ['1590406001', '3-8053-1685-2']
# ['300709002', '3-402-06243-7']
# ['1550268002', '3-922027-88-1']
# ['401509001', '3-910011-05-5']
# ['1590407001', '3-7995-3628-0']
# ['215431003', 'FALSE']
# ['1590408001', 'FALSE']
# ['1590410001', 'FALSE']
# ['1590411001', '3-908025-46-X']
# ['1590413001', '3-7608-3649-6']
# ['1590414001', '3-7757-0557-0']
# ['1200217002', '3-926011-28-9']
# ['506545002', 'FALSE']
# ['801704002', 'FALSE']
# ['509097004', '3-7923-0680-8']
# ['1866010', '3-927789-78-X']
# ['301492002', '388789-117-1']
# ['1590417001', 'FALSE']
# ['1605455001', 'FALSE']
# ['1590419001', 'FALSE']
# ['1590423001', 'FALSE']
# ['1590425001', '3-406-04801-3']
# ['215648002', 'FALSE']
# ['215649002', 'FALSE']
# ['215650002', '3-525-35377-4']
# ['1501409001', '3-525-35436-3']
# ['1501410003', '3-525-35311-1']
# ['1560685001', '3-525-35309-X']
# ['1560686001', '978-3-525-36521-2']
# ['1590437001', '3-534-04685-4']
# ['1590440001', '3-534-04166-6']
# ['1590444001', 'FALSE']
# ['1590446001', '3-8062-0293-1']
# ['1590449001', '3-900401-39-2']
# ['1590450001', 'FALSE']
# ['1590573001', 'FALSE']
# ['1590577001', 'FALSE']
# ['127020002', 'FALSE']
# ['1590590001', 'FALSE']
# ['1590591001', 'FALSE']
# ['1590593001', 'FALSE']
# ['1590594001', 'FALSE']
# ['1590595001', 'FALSE']
# ['215507003', 'FALSE']
# ['1590596001', 'FALSE']
# ['1590597001', 'FALSE']
# ['1590599001', 'FALSE']
# ['1590601001', 'FALSE']
# ['1590603001', 'FALSE']
# ['1590605001', '3-922616-00-3']
# ['215517002', 'FALSE']
# ['1590606001', 'FALSE']
# ['1590607001', 'FALSE']
# ['1590610001', 'FALSE']
# ['1590612001', 'FALSE']
# ['1590614001', 'FALSE']
# ['1590616001', 'FALSE']
# ['8445005', 'FALSE']
# ['1590617001', 'FALSE']
# ['1590618001', '3-406-03172-2']
# ['1590621001', 'FALSE']
# ['1590622001', 'FALSE']
# ['1590624001', 'FALSE']
# ['1590626001', 'FALSE']
# ['1590629001', 'FALSE']
# ['1590631001', 'FALSE']
# ['1590633001', 'FALSE']
# ['1590634001', 'FALSE']
# ['1590635001', 'FALSE']
# ['1590636001', '3-406-09041-9']
# ['1605446001', 'FALSE']
# ['1605450001', 'FALSE']
# ['1605451001', 'FALSE']
# ['1590637001', '82-90215-80-0']
# ['1590638001', '3-534-03870-3']
# ['1590639001', 'FALSE']
# ['1590641001', 'FALSE']
# ['1590642001', 'FALSE']
# ['1590643001', 'FALSE']
# ['1590645001', '963-7421-37-8']
# ['215771002', 'FALSE']
# ['215770002', 'FALSE']
# ['1590649001', 'FALSE']
# ['1590652001', 'FALSE']
# ['1590654001', 'FALSE']
# ['1590660001', '3-406-06775-1']
# ['1590665001', 'FALSE']
# ['1590667001', 'FALSE']
# ['1590669001', 'FALSE']
# ['1590670001', 'FALSE']
# ['1590671001', 'FALSE']
# ['1590674001', 'FALSE']
# ['1590676001', 'FALSE']
# ['1590677001', 'FALSE']
# ['1590686001', 'FALSE']
# ['1590687001', 'FALSE']
# ['1590688001', 'FALSE']
# ['1590689001', '3-929055-36-8']
# ['1590690001', 'FALSE']
# ['1590691001', 'FALSE']
# ['1590693001', 'FALSE']
# ['1590694001', 'FALSE']
# ['1590695001', 'FALSE']
# ['1590696001', 'FALSE']
# ['1590697001', 'FALSE']
# ['1590698001', 'FALSE']
# ['1590699001', 'FALSE']
# ['1590700001', 'FALSE']
# ['1590701001', 'FALSE']
# ['1590702001', 'FALSE']

# %% [markdown]
# # Exkurs/Schritt 5: Eingabe in google spreadsheet
# 5.1: Es gibt ein Google Spreadsheet, in dem man ISBN testweise eingeben kann: https://docs.google.com/spreadsheets/d/1hZ92Pxgw2hbiTVmTG0XAGNMPYzN6wmvm-mrLPvZ-eoM/edit#gid=0
# 5.2: dies ermöglicht die Ausgabe von RVK-Notationen für eingegebene ISBN
# 5.3: RVK-Notationen können aber auch importiert werden, z.B. =ImportJSON("http://data.bib.uni-mannheim.de/malibu/isbn/swb.php?isbn="ISBN"&format=json"; "/rvk"; "noHeaders")
# 5.4: Befehl ausführen: JSON-basierte Antwortdaten (s. https://2.python-requests.org//de/latest/user/quickstart.html)

# %%
import requests
r = requests.get('http://data.bib.uni-mannheim.de/malibu/isbn/gbv.php?isbn=3-85460-115-8&format=json')
r.json()
# Out:
# {'id': ['316021121'],
#  'isbn': ['3854601158'],
#  'dnbNr': '',
#  'oclcNr': ['165236530'],
#  'titel': ['Sie sahen die Mauern Trojas'],
#  'untertitel': ['Kunstgewerbe der Bronzezeit in Südostungarn : Sonderausstellung im Museum für Urgeschichte, Aspern/Zaya, 1. April - 15. Nov. 1994'],
#  'autor': ['Otto Trogmayer, Gabriella Vörös'],
#  'gesamttitel': ['Katalog des Niederösterreichischen Landesmuseums N.F. 348'],
#  'hochschulvermerk': '',
#  'auflage': '',
#  'erscheinungsinfo': ['Aspern/Zaya', 'Museum für Urgeschichte', '1994'],
#  'umfang': ['34 Seiten', 'Illustrationen'],
#  'links': '',
#  'bestand': ['ZK Sachsen Anhalt',
#   'SUB+Uni Hamburg <18>',
#   'ULB Halle <3>',
#   'LDA Halle <Ha 91>',
#   'PKB (Museen) Berlin',
#   'Museen+Denkmalschutzamt HH'],
#  'rvk': ['NF 1665'],
#  'ddc': '',
#  'sw': [],
#  'produktSigel': '',
#  'einzelaufnahmen': [{'id': ['316021121'],
#    'isbn': ['3854601158'],
#    'dnbNr': '',
#    'oclcNr': ['165236530'],
#    'titel': ['Sie sahen die Mauern Trojas'],
#    'untertitel': ['Kunstgewerbe der Bronzezeit in Südostungarn : Sonderausstellung im Museum für Urgeschichte, Aspern/Zaya, 1. April - 15. Nov. 1994'],
#    'autor': ['Otto Trogmayer, Gabriella Vörös'],
#    'gesamttitel': ['Katalog des Niederösterreichischen Landesmuseums N.F. 348'],
#    'hochschulvermerk': '',
#    'auflage': '',
#    'erscheinungsinfo': ['Aspern/Zaya', 'Museum für Urgeschichte', '1994'],
#    'umfang': ['34 Seiten', 'Illustrationen'],
#    'links': '',
#    'bestand': ['ZK Sachsen Anhalt',
#     'SUB+Uni Hamburg <18>',
#     'ULB Halle <3>',
#     'LDA Halle <Ha 91>',
#     'PKB (Museen) Berlin',
#     'Museen+Denkmalschutzamt HH'],
#    'rvk': ['NF 1665'],
#    'ddc': '',
#    'sw': [],
#    'produktSigel': ''}]}

# %% [markdown]
# # Schritt 6: RVK-Notationen auslesen
# 6.1: Die RVK-Notationen (= Werte) befinden sich unter dem Key 'rvk' ('rvk': ['NF 1665'])
# 6.2: nächster Schritt: Notationen auslesen lassen für ISBN

# %%
import requests

# %%
r = requests.get('http://data.bib.uni-mannheim.de/malibu/isbn/gbv.php?isbn=3-85460-115-8&format=json')

# %%
r.text
# Out:
# '{\n    "id": [\n        "316021121"\n    ],\n    "isbn": [\n        "3854601158"\n    ],\n    "dnbNr": "",\n    "oclcNr": [\n        "165236530"\n    ],\n    "titel": [\n        "Sie sahen die Mauern Trojas"\n    ],\n    "untertitel": [\n        "Kunstgewerbe der Bronzezeit in S\\u00fcdostungarn : Sonderausstellung im Museum f\\u00fcr Urgeschichte, Aspern\\/Zaya, 1. April - 15. Nov. 1994"\n    ],\n    "autor": [\n        "Otto Trogmayer, Gabriella V\\u00f6r\\u00f6s"\n    ],\n    "gesamttitel": [\n        "Katalog des Nieder\\u00f6sterreichischen Landesmuseums N.F. 348"\n    ],\n    "hochschulvermerk": "",\n    "auflage": "",\n    "erscheinungsinfo": [\n        "Aspern\\/Zaya",\n        "Museum f\\u00fcr Urgeschichte",\n        "1994"\n    ],\n    "umfang": [\n        "34 Seiten",\n        "Illustrationen"\n    ],\n    "links": "",\n    "bestand": [\n        "ZK Sachsen Anhalt",\n        "SUB+Uni Hamburg <18>",\n        "ULB Halle <3>",\n        "LDA Halle <Ha 91>",\n        "PKB (Museen) Berlin",\n        "Museen+Denkmalschutzamt HH"\n    ],\n    "rvk": [\n        "NF 1665"\n    ],\n    "ddc": "",\n    "sw": [],\n    "produktSigel": "",\n    "einzelaufnahmen": [\n        {\n            "id": [\n                "316021121"\n            ],\n            "isbn": [\n                "3854601158"\n            ],\n            "dnbNr": "",\n            "oclcNr": [\n                "165236530"\n            ],\n            "titel": [\n                "Sie sahen die Mauern Trojas"\n            ],\n            "untertitel": [\n                "Kunstgewerbe der Bronzezeit in S\\u00fcdostungarn : Sonderausstellung im Museum f\\u00fcr Urgeschichte, Aspern\\/Zaya, 1. April - 15. Nov. 1994"\n            ],\n            "autor": [\n                "Otto Trogmayer, Gabriella V\\u00f6r\\u00f6s"\n            ],\n            "gesamttitel": [\n                "Katalog des Nieder\\u00f6sterreichischen Landesmuseums N.F. 348"\n            ],\n            "hochschulvermerk": "",\n            "auflage": "",\n            "erscheinungsinfo": [\n                "Aspern\\/Zaya",\n                "Museum f\\u00fcr Urgeschichte",\n                "1994"\n            ],\n            "umfang": [\n                "34 Seiten",\n                "Illustrationen"\n            ],\n            "links": "",\n            "bestand": [\n                "ZK Sachsen Anhalt",\n                "SUB+Uni Hamburg <18>",\n                "ULB Halle <3>",\n                "LDA Halle <Ha 91>",\n                "PKB (Museen) Berlin",\n                "Museen+Denkmalschutzamt HH"\n            ],\n            "rvk": [\n                "NF 1665"\n            ],\n            "ddc": "",\n            "sw": [],\n            "produktSigel": ""\n        }\n    ]\n}'

# %%
#Key und Value lautet "rvk": [\n        "NF 1665"\n    ]
# Wie erhalte ich eine automatische Eingabe der Spalte ISBN in den Query String? (s. http://www.compciv.org/guides/python/how-tos/creating-proper-url-query-strings/)

# %%
#Schritt 7: ISBN in Query String setzen  
7.1: Wenn die ISBN aus der Spalte "ISBN" der csv in den Query String gesetzt wird, können Abfragen für alle in der Liste vorhandenen ISBN druchgeführt werden
7.2: Wie können Werte der Spalte "ISBN" in den String gebracht werden: 'http://data.bib.uni-mannheim.de/malibu/isbn/gbv.php?isbn=3-85460-115-8&format=json'

# %%
from urllib.request import urlretrieve

# %%
thing = urlretrieve("http://data.bib.uni-mannheim.de/malibu/isbn/gbv.php?isbn=978-3-8006-4582-4&format=json")

# %%
from urllib.parse import quote

# %%
qstr = {3-85460-115-8}
# hier müsste die Spalte "ISBN" aus der csv definiert werden
thing = urlretrieve("http://data.bib.uni-mannheim.de/malibu/isbn/gbv.php?isbn=" + qstr + "&format=json")
# so müsste der String danach aufgebaut sein

# %%
from urllib.parse import urlencode
